# %% [markdown]
# **UBER COMMENTS SENTIMENT ANALYSIS**
#
# Table of content
#
# 1. **DATA PREPARATION**
# - check data consistency
# - removing all useless characters
# - data optimization (dimensionality reduction)
#
# 2. **SENTIMENT ANALYSIS**
# - vader score computation
# - classification
#
# 3. **LOGISTIC REGRESSION**
# - baseline model
# - hyperparameter tuning
#
# 4. **INTERPRETATION AND ANALYSIS**
# - sentiment distribution
# - sentiment VS time
# - sentiment VS hour of a day
# - Explaining sentiment : What stands out of the comments ?
# - Explaining sentiment : What made people so satisfied in early December ?

# %%
from tqdm import tqdm
import numpy as np
import pandas as pd
from itertools import accumulate
import matplotlib.pyplot as plt
import seaborn as sns
import multiprocessing

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from scipy.stats import uniform, loguniform

import string
import re

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import wordnet

nltk.download('vader_lexicon')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')

from xgboost import XGBClassifier
import xgboost as xgb

from collections import Counter
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/gabin/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/gabin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/gabin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /Users/gabin/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/gabin/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv('uber_reviews_without_reviewid.csv.xls')
df.head(10)
# Out:
#   userName  userImage                                            content  \
# 0   User_0        NaN                                               Good
# 1   User_1        NaN                                               Nice
# 2   User_2        NaN                                    Very convenient
# 3   User_3        NaN                                               Good
# 4   User_4        NaN                                           exllence
# 5   User_5        NaN  Michelle was a very friendly and personable pe...
# 6   User_6        NaN                        Bast price pr car available
# 7   User_7        NaN                                       Good service
# 8   User_8        NaN                                            Awesome
# 9   User_9        NaN                                         Nice 🙂🙂🙂🙂🙂
#
#    score  thumbsUpCount reviewCreatedVersion                   at  \
# 0      5              0          4.556.10005  2024-12-18 17:17:19
# 1      5              0          4.556.10005  2024-12-18 17:17:17
# 2      5              0          4.532.10001  2024-12-18 17:09:42
# 3      4              0          4.556.10005  2024-12-18 17:08:27
# 4      5              0          4.556.10005  2024-12-18 17:08:16
# 5      5              0          4.556.10005  2024-12-18 17:06:09
# 6      5              0          4.556.10005  2024-12-18 17:06:04
# 7      5              0          4.556.10005  2024-12-18 17:05:20
# 8      5              0          4.556.10005  2024-12-18 17:05:10
# 9      5              0          4.556.10005  2024-12-18 17:04:02
#
#   replyContent repliedAt   appVersion
# 0          NaN       NaN  4.556.10005
# 1          NaN       NaN  4.556.10005
# 2          NaN       NaN  4.532.10001
# 3          NaN       NaN  4.556.10005
# 4          NaN       NaN  4.556.10005
# 5          NaN       NaN  4.556.10005
# 6          NaN       NaN  4.556.10005
# 7          NaN       NaN  4.556.10005
# 8          NaN       NaN  4.556.10005
# 9          NaN       NaN  4.556.10005

# %% [markdown]
# 1. **DATA PREPARATION**
#
# DATA CONSISTENCY

# %% [markdown]
# Let is drop the columns we will not use

# %%
df = df.drop(columns=['userImage', 'reviewCreatedVersion', 'replyContent','repliedAt', 'appVersion'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   userName       12000 non-null  object
#  1   content        12000 non-null  object
#  2   score          12000 non-null  int64
#  3   thumbsUpCount  12000 non-null  int64
#  4   at             12000 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 468.9+ KB

# %% [markdown]
# "at" record the timestamp of the comment: let is change its format from object to datetime

# %%
df['at'] = pd.to_datetime(df['at'])

# %% [markdown]
# REMOVING ALL USELESS CHARACTERS

# %% [markdown]
# The d_types are correct. To continue the implementation of sentiment analysis, it is necessary to put all text objects in lower case, let is do it !

# %%
df['new_content'] = df['content'].str.lower()
df.sample(3)
# Out:
#          userName                                            content  score  \
# 8333    User_8333                               Good budget friendly      5
# 6329    User_6329  The worst cab app , i booked bike and he took ...      1
# 10982  User_10982  Most awful horrible company you can't get a ho...      1
#
#        thumbsUpCount                  at  \
# 8333               0 2024-12-01 19:03:07
# 6329               0 2024-12-05 08:46:23
# 10982              0 2024-11-26 21:28:05
#
#                                              new_content
# 8333                                good budget friendly
# 6329   the worst cab app , i booked bike and he took ...
# 10982  most awful horrible company you can't get a ho...

# %% [markdown]
# To handle misinterpretation issues, it is intersteing to transform formulation with negation to "positive affirmation"
#  (I am not very happy -> I am unhappy) Without doing this  "happy" would have been considered as a positive word and corrupt the sentiment of the comment.

# %%
def negate(sentence):
    temp = int(0)
    for i in range(len(sentence)):
        if sentence[i-1] in ['not',"n't"]:
            antonyms = []
            for syn in wordnet.synsets(sentence[i]):
                syns = wordnet.synsets(sentence[i])
                w1 = syns[0].name()
                temp = 0
                for l in syn.lemmas():
                    if l.antonyms():
                        antonyms.append(l.antonyms()[0].name())
                        max_dissimilarity = 0
                        for ant in antonyms:
                            syns = wordnet.synsets(ant)
                            w2 = syns[0].name()
                            syns = wordnet.synsets(sentence[i])
                            w1 = syns[0].name()
                            word1 = wordnet.synset(w1)
                            word2 = wordnet.synset(w2)
                            if isinstance(word1.wup_similarity(word2), float) or isinstance(word1.wup_similarity(word2), int):
                                temp = 1 - word1.wup_similarity(word2)
                                if temp>max_dissimilarity:
                                    max_dissimilarity = temp
                                    antonym_max = ant
                                    sentence[i] = antonym_max
                                    sentence[i-1] = ''
    while '' in sentence:
        sentence.remove('')
    return sentence

# %% [markdown]
# Now that the fonction is defined, let is apply it to our content

# %%
df['new_content'] = df['new_content'].apply(lambda x: negate(word_tokenize(x)))
df.head(5)
# Out:
#   userName          content  score  thumbsUpCount                  at  \
# 0   User_0             Good      5              0 2024-12-18 17:17:19
# 1   User_1             Nice      5              0 2024-12-18 17:17:17
# 2   User_2  Very convenient      5              0 2024-12-18 17:09:42
# 3   User_3             Good      4              0 2024-12-18 17:08:27
# 4   User_4         exllence      5              0 2024-12-18 17:08:16
#
#           new_content
# 0              [good]
# 1              [nice]
# 2  [very, convenient]
# 3              [good]
# 4          [exllence]

# %% [markdown]
# In order to apply negate function we had to tokenize the content. Since it not necessary anymore, let is  unlist eevrything

# %%
def unlist(list):
    words=''
    for item in list:
        words+=item+' '
    return words

# %%
df['new_content'] = df['new_content'].apply(lambda x: unlist(x))
df.head()
# Out:
#   userName          content  score  thumbsUpCount                  at  \
# 0   User_0             Good      5              0 2024-12-18 17:17:19
# 1   User_1             Nice      5              0 2024-12-18 17:17:17
# 2   User_2  Very convenient      5              0 2024-12-18 17:09:42
# 3   User_3             Good      4              0 2024-12-18 17:08:27
# 4   User_4         exllence      5              0 2024-12-18 17:08:16
#
#         new_content
# 0             good
# 1             nice
# 2  very convenient
# 3             good
# 4         exllence

# %% [markdown]
# The contents are full of punctuations that will not be useful to our analysis. Let is delete them.

# %%
punc = string.punctuation
print("The punctuation signs in Python are: " + punc)

def delete_punc(text):
    text_wo_punc = text.translate(str.maketrans("", "", punc))
    return text_wo_punc
# Out:
# The punctuation signs in Python are: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
df['new_content'] = df['new_content'].apply(lambda text: delete_punc(text))
df.head(2)
# Out:
#   userName content  score  thumbsUpCount                  at new_content
# 0   User_0    Good      5              0 2024-12-18 17:17:19       good
# 1   User_1    Nice      5              0 2024-12-18 17:17:17       nice

# %% [markdown]
# Then we can remove "banal" or "neutral" words that does not bring anything to the sentiment analysis

# %%
print("The stopwords in English are: ")
", ".join(stopwords.words("english"))

to_stop = set(stopwords.words("english"))

def delete_stopwords(text):
    # tokenize words in text
    word_tokens = word_tokenize(text)
    removed = [word for word in word_tokens if not word in to_stop]
    new_text = " ".join(removed)
    return new_text
# Out:
# The stopwords in English are:

# %%
df['new_content'] = df['new_content'].apply(lambda text: delete_stopwords(text))
df.sample(1, random_state = 2024)
# Out:
#        userName content  score  thumbsUpCount                  at new_content
# 3835  User_3835  Good 👍      5              0 2024-12-10 13:06:49      good 👍

# %% [markdown]
# Then, we can find in the content : numbers, url or email. These pieces of text are also useless and should not corrupt the analysis so let is remove them

# %%
def remove_num_url_email(text):
    text = re.sub('@[^\s]+', ' ', text)
    text = re.sub("((http:\/\/www\.)|(www\.)|(http:\/\/))[a-zA-Z0-9._-]+\.[a-zA-Z.]{2,5}", "", text)
    text = re.sub('[0-9]+', '', text)
    return text
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\/'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\/'
# /var/folders/xk/_lxyx6nn61b0nzyx5vp0p0ph0000gn/T/ipykernel_80109/3091105778.py:2: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('@[^\s]+', ' ', text)
# /var/folders/xk/_lxyx6nn61b0nzyx5vp0p0ph0000gn/T/ipykernel_80109/3091105778.py:3: SyntaxWarning: invalid escape sequence '\/'
#   text = re.sub("((http:\/\/www\.)|(www\.)|(http:\/\/))[a-zA-Z0-9._-]+\.[a-zA-Z.]{2,5}", "", text)

# %%
df['new_content'] = df['new_content'].apply(lambda x: remove_num_url_email(x))
df.tail(2)
# Out:
#          userName                                            content  score  \
# 11998  User_11998                                      Good Service.      5
# 11999  User_11999  Very bad experience with this app, booked a sh...      1
#
#        thumbsUpCount                  at  \
# 11998              0 2024-11-24 21:50:30
# 11999              0 2024-11-24 21:44:44
#
#                                              new_content
# 11998                                       good service
# 11999  bad experience app booked short ride rs unwant...

# %% [markdown]
# DATA OPTIMIZATION (dimensionality reduction)

# %% [markdown]
# At this point we have deleted all useless content in the comments. Let is now work on the core of the messages. We will first use **lemmatization** before **stemming** in order to reduce dimmensionality of the content focusing on the key sentiment rather than singular way to express them.
# To do so, we first need to tokenize the content so we are able isolate individual words and process them.

# %% [markdown]
# Tokenisation

# %%
tokenizer = RegexpTokenizer(r'\w+')
df['new_content'] = df['new_content'].apply(tokenizer.tokenize)
df.head(2)
# Out:
#   userName content  score  thumbsUpCount                  at new_content
# 0   User_0    Good      5              0 2024-12-18 17:17:19      [good]
# 1   User_1    Nice      5              0 2024-12-18 17:17:17      [nice]

# %% [markdown]
# Lemmatization

# %%
lemm = nltk.WordNetLemmatizer()
def lemmatize_text(text):
    newtext = [lemm.lemmatize(word) for word in text]
    return text

df['new_content'] = df['new_content'].apply(lambda x: lemmatize_text(x))
df.head(2)
# Out:
#   userName content  score  thumbsUpCount                  at new_content
# 0   User_0    Good      5              0 2024-12-18 17:17:19      [good]
# 1   User_1    Nice      5              0 2024-12-18 17:17:17      [nice]

# %% [markdown]
# stemming

# %%
stem = nltk.PorterStemmer()
def stem_text(text):
    stemmed = [stem.stem(word) for word in text]
    return stemmed

df['new_content']= df['new_content'].apply(lambda x: stem_text(x))
df.tail(5)
# Out:
#          userName                                            content  score  \
# 11995  User_11995                                       Excellent!!!      5
# 11996  User_11996  Worst experience after 10pm in Hyde cityno aut...      5
# 11997  User_11997                                        Exceptional      5
# 11998  User_11998                                      Good Service.      5
# 11999  User_11999  Very bad experience with this app, booked a sh...      1
#
#        thumbsUpCount                  at  \
# 11995              0 2024-11-24 21:59:16
# 11996              0 2024-11-24 21:56:10
# 11997              0 2024-11-24 21:52:21
# 11998              0 2024-11-24 21:50:30
# 11999              0 2024-11-24 21:44:44
#
#                                              new_content
# 11995                                            [excel]
# 11996  [worst, experi, pm, hyde, cityno, auto, take, ...
# 11997                                           [except]
# 11998                                     [good, servic]
# 11999  [bad, experi, app, book, short, ride, rs, unwa...

# %% [markdown]
# I will rename the new columns for more clarity (probably should have done it before)

# %%
df.rename(columns = {'content': 'original_content', 
                     'new_content': 'content_lst'}, inplace = True)
df.tail()
# Out:
#          userName                                   original_content  score  \
# 11995  User_11995                                       Excellent!!!      5
# 11996  User_11996  Worst experience after 10pm in Hyde cityno aut...      5
# 11997  User_11997                                        Exceptional      5
# 11998  User_11998                                      Good Service.      5
# 11999  User_11999  Very bad experience with this app, booked a sh...      1
#
#        thumbsUpCount                  at  \
# 11995              0 2024-11-24 21:59:16
# 11996              0 2024-11-24 21:56:10
# 11997              0 2024-11-24 21:52:21
# 11998              0 2024-11-24 21:50:30
# 11999              0 2024-11-24 21:44:44
#
#                                              content_lst
# 11995                                            [excel]
# 11996  [worst, experi, pm, hyde, cityno, auto, take, ...
# 11997                                           [except]
# 11998                                     [good, servic]
# 11999  [bad, experi, app, book, short, ride, rs, unwa...

# %% [markdown]
# Just as before let is unlist everything after the tokenization as we finsihed processing the data.

# %%
df['content_nlst'] = df['content_lst'].apply(lambda x: unlist(x))
df.tail()
# Out:
#          userName                                   original_content  score  \
# 11995  User_11995                                       Excellent!!!      5
# 11996  User_11996  Worst experience after 10pm in Hyde cityno aut...      5
# 11997  User_11997                                        Exceptional      5
# 11998  User_11998                                      Good Service.      5
# 11999  User_11999  Very bad experience with this app, booked a sh...      1
#
#        thumbsUpCount                  at  \
# 11995              0 2024-11-24 21:59:16
# 11996              0 2024-11-24 21:56:10
# 11997              0 2024-11-24 21:52:21
# 11998              0 2024-11-24 21:50:30
# 11999              0 2024-11-24 21:44:44
#
#                                              content_lst  \
# 11995                                            [excel]
# 11996  [worst, experi, pm, hyde, cityno, auto, take, ...
# 11997                                           [except]
# 11998                                     [good, servic]
# 11999  [bad, experi, app, book, short, ride, rs, unwa...
#
#                                             content_nlst
# 11995                                             excel
# 11996        worst experi pm hyde cityno auto take ride
# 11997                                            except
# 11998                                       good servic
# 11999  bad experi app book short ride rs unwant unnam...

# %% [markdown]
# 2. **SENTIMENT ANALYSIS**

# %% [markdown]
# Now that the data is ready we proceed to the sentiment analysis. To do so it is preferabel to work on a differneet DataFrame and the add the final result of the analysis to the orginal dataframe.
#
#
# VADER SCORE COMPUTATIONS
#
# First, let is compute the vader scores indicating how much a comment is positve, neutral or negative.

# %%
vaderScores = pd.DataFrame()
vaderScores['original_content'] = df['original_content']
vaderScores['content'] = df['content_nlst']

def compute_vader_scores(df, label):
    sid = SentimentIntensityAnalyzer()
    df["vader_neg"] = df[label].apply(lambda x: sid.polarity_scores(x)["neg"])
    df["vader_neu"] = df[label].apply(lambda x: sid.polarity_scores(x)["neu"])
    df["vader_pos"] = df[label].apply(lambda x: sid.polarity_scores(x)["pos"])
    df["vader_comp"] = df[label].apply(lambda x: sid.polarity_scores(x)["compound"])
    return df

vaderScores = compute_vader_scores(vaderScores,'content')
vaderScores.sample(3, random_state = 2)
# Out:
#      original_content       content  vader_neg  vader_neu  vader_pos  \
# 7104             Good         good         0.0      0.000      1.000
# 5878             Good         good         0.0      0.000      1.000
# 7311     Best service  best servic         0.0      0.192      0.808
#
#       vader_comp
# 7104      0.4404
# 5878      0.4404
# 7311      0.6369

# %% [markdown]
# CLASSIFICATION
#
# **vader_comp** corresponds to the ponderated sum of all scores giving insights on the sentiment of the comment.
#
# Based on the previous result it is now possible to classify every comment :
#
# - vader_comp between -1 and -0,05 -> **negative**
# - vader_comp between -0,05 and 0,05 -> **neutral**
# - vader_comp between 0,05 and 1 -> **positive**

# %%
vaderScores['target'] = np.where(vaderScores['vader_comp'] >= 0.05, 1, np.where(vaderScores['vader_comp'] <= -0.05, -1, 0))
vaderScores.sample(3, random_state = 2)
# Out:
#      original_content       content  vader_neg  vader_neu  vader_pos  \
# 7104             Good         good         0.0      0.000      1.000
# 5878             Good         good         0.0      0.000      1.000
# 7311     Best service  best servic         0.0      0.192      0.808
#
#       vader_comp  target
# 7104      0.4404       1
# 5878      0.4404       1
# 7311      0.6369       1

# %% [markdown]
# We can finally add the new column sentiment to the orginal dataset

# %%
df['sentiment'] = vaderScores['target']
df.sample(3, random_state = 2)
# Out:
#        userName original_content  score  thumbsUpCount                  at  \
# 7104  User_7104             Good      5              0 2024-12-03 20:32:11
# 5878  User_5878             Good      5              0 2024-12-06 07:29:11
# 7311  User_7311     Best service      5              0 2024-12-03 12:55:11
#
#          content_lst  content_nlst  sentiment
# 7104          [good]         good           1
# 5878          [good]         good           1
# 7311  [best, servic]  best servic           1

# %% [markdown]
# 3. **LOGISTIC REGRESSION**
#
# We could have stopped here and and started out analysis but let is take advantage of our new datatset to perform a logistic regression with XGBoost Classifier.

# %% [markdown]
# Let is start by split and vectorize the data to fit the requirements from XGboost classifier.

# %%
X = df['content_nlst']
y = df['sentiment']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,stratify=df['sentiment'], random_state=24) 

# Vectorization
tfidf_vectorizer = TfidfVectorizer(max_features=5000, stop_words = 'english')
X_train_vec = tfidf_vectorizer.fit_transform(X_train)
X_test_vec = tfidf_vectorizer.transform(X_test)

# %%
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
vader = SentimentIntensityAnalyzer()

# Perform sentiment analysis using VADER on the training set
train_sent = [vader.polarity_scores(text)['compound'] for text in X_train]

# Convert the sentiment scores to target labels: 1 is positive, 0 is neutral, -1 is negative:
train_pred = [1 if score >= 0.05 else -1 if score <= -0.05 else 0 for score in train_sent]

# %% [markdown]
# BASELINE MODEL

# %%
xgbc = XGBClassifier(max_depth=5, n_estimators = 1000, nthread = 3)
xgbc.fit(X_train_vec, y_train_encoded)
prediction_xgb = xgbc.predict(X_test_vec)
print(f"Accuracy: {accuracy_score(prediction_xgb, y_test_encoded):.2%}")
# Out:
# Accuracy: 93.86%

# %% [markdown]
# An accuracy of 93,9% is already pretty satisfying but let is see how much we can improve it.

# %% [markdown]
# HYPERPARAMETERS TUNNING
#
# Let is try to imporve accuracy by testing randomly different hyperparameters "composition" using RandomizedSearchCV
# For a cleaner test we wil use pipeline

# %%
cpu_count = multiprocessing.cpu_count()
# define the range of hyperparameters we are likely to test
param_dist = {"classifier__learning_rate": uniform(0.000001, 0.3),
              "classifier__max_depth": range(2,5),
              "classifier__n_estimators": range(500,1001),
              "classifier__min_child_weight": loguniform(1,5),
              "classifier__max_delta_step": range(0,11)
             }

#define the pipeline
classifier = XGBClassifier(n_jobs=cpu_count, seed=2024)
model_pipeline  = Pipeline([
    ('tfidf', TfidfVectorizer(max_features=5000, stop_words = 'english')),
    ('classifier', classifier)
])

#test random "composition" of hyperparameters
rs = RandomizedSearchCV(model_pipeline, scoring='accuracy',
                        param_distributions=param_dist,
                        n_iter=25, n_jobs=1, random_state=2024, verbose=2)

rs.fit(X_train, y_train_encoded)

# Get and store the best hyperparameters
model_params = {'n_jobs':cpu_count, 'seed':2024}
best_params = {x.split('__')[1]:rs.best_params_[x] for x in rs.best_params_}
model_params.update(best_params)
model = XGBClassifier(**model_params)
model.fit(X_train_vec, y_train_encoded)
predictions=model.predict(X_test_vec)

print('Accuracy: ', round(accuracy_score(y_test_encoded, predictions)*100,2), '%')
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] END classifier__learning_rate=0.17640535566861937, classifier__max_delta_step=0, classifier__max_depth=2, classifier__min_child_weight=1.3536692897350402, classifier__n_estimators=946; total time=   3.4s
# [CV] END classifier__learning_rate=0.17640535566861937, classifier__max_delta_step=0, classifier__max_depth=2, classifier__min_child_weight=1.3536692897350402, classifier__n_estimators=946; total time=   3.0s
# [CV] END classifier__learning_rate=0.17640535566861937, classifier__max_delta_step=0, classifier__max_depth=2, classifier__min_child_weight=1.3536692897350402, classifier__n_estimators=946; total time=   3.0s
# [CV] END classifier__learning_rate=0.17640535566861937, classifier__max_delta_step=0, classifier__max_depth=2, classifier__min_child_weight=1.3536692897350402, classifier__n_estimators=946; total time=   3.0s
# [CV] END classifier__learning_rate=0.17640535566861937, classifier__max_delta_step=0, classifier__max_depth=2, classifier__min_child_weight=1.3536692897350402, classifier__n_estimators=946; total time=   2.8s
# [CV] END classifier__learning_rate=0.26791521146322544, classifier__max_delta_step=1, classifier__max_depth=2, classifier__min_child_weight=3.2234359591077917, classifier__n_estimators=822; total time=   2.0s
# [CV] END classifier__learning_rate=0.26791521146322544, classifier__max_delta_step=1, classifier__max_depth=2, classifier__min_child_weight=3.2234359591077917, classifier__n_estimators=822; total time=   2.2s
# [CV] END classifier__learning_rate=0.26791521146322544, classifier__max_delta_step=1, classifier__max_depth=2, classifier__min_child_weight=3.2234359591077917, classifier__n_estimators=822; total time=   2.0s
# [CV] END classifier__learning_rate=0.26791521146322544, classifier__max_delta_step=1, classifier__max_depth=2, classifier__min_child_weight=3.2234359591077917, classifier__n_estimators=822; total time=   2.0s
# [CV] END classifier__learning_rate=0.26791521146322544, classifier__max_delta_step=1, classifier__max_depth=2, classifier__min_child_weight=3.2234359591077917, classifier__n_estimators=822; total time=   2.0s
# [CV] END classifier__learning_rate=0.20086751922876914, classifier__max_delta_step=1, classifier__max_depth=4, classifier__min_child_weight=1.0312291562041878, classifier__n_estimators=702; total time=   4.3s
# [CV] END classifier__learning_rate=0.20086751922876914, classifier__max_delta_step=1, classifier__max_depth=4, classifier__min_child_weight=1.0312291562041878, classifier__n_estimators=702; total time=   4.4s
# [CV] END classifier__learning_rate=0.20086751922876914, classifier__max_delta_step=1, classifier__max_depth=4, classifier__min_child_weight=1.0312291562041878, classifier__n_estimators=702; total time=   5.0s
# [CV] END classifier__learning_rate=0.20086751922876914, classifier__max_delta_step=1, classifier__max_depth=4, classifier__min_child_weight=1.0312291562041878, classifier__n_estimators=702; total time=   4.7s
# [CV] END classifier__learning_rate=0.20086751922876914, classifier__max_delta_step=1, classifier__max_depth=4, classifier__min_child_weight=1.0312291562041878, classifier__n_estimators=702; total time=   4.4s
# [CV] END classifier__learning_rate=0.27501501514362214, classifier__max_delta_step=7, classifier__max_depth=4, classifier__min_child_weight=1.4773065637748914, classifier__n_estimators=829; total time=   4.6s
# [CV] END classifier__learning_rate=0.27501501514362214, classifier__max_delta_step=7, classifier__max_depth=4, classifier__min_child_weight=1.4773065637748914, classifier__n_estimators=829; total time=   4.9s
# [CV] END classifier__learning_rate=0.27501501514362214, classifier__max_delta_step=7, classifier__max_depth=4, classifier__min_child_weight=1.4773065637748914, classifier__n_estimators=829; total time=   4.9s
# [CV] END classifier__learning_rate=0.27501501514362214, classifier__max_delta_step=7, classifier__max_depth=4, classifier__min_child_weight=1.4773065637748914, classifier__n_estimators=829; total time=   4.8s
# [CV] END classifier__learning_rate=0.27501501514362214, classifier__max_delta_step=7, classifier__max_depth=4, classifier__min_child_weight=1.4773065637748914, classifier__n_estimators=829; total time=   5.0s
# [CV] END classifier__learning_rate=0.06760724895780866, classifier__max_delta_step=4, classifier__max_depth=4, classifier__min_child_weight=3.26797539727096, classifier__n_estimators=650; total time=   4.0s
# [CV] END classifier__learning_rate=0.06760724895780866, classifier__max_delta_step=4, classifier__max_depth=4, classifier__min_child_weight=3.26797539727096, classifier__n_estimators=650; total time=   3.9s
# [CV] END classifier__learning_rate=0.06760724895780866, classifier__max_delta_step=4, classifier__max_depth=4, classifier__min_child_weight=3.26797539727096, classifier__n_estimators=650; total time=   3.9s
# [CV] END classifier__learning_rate=0.06760724895780866, classifier__max_delta_step=4, classifier__max_depth=4, classifier__min_child_weight=3.26797539727096, classifier__n_estimators=650; total time=   3.7s
# [CV] END classifier__learning_rate=0.06760724895780866, classifier__max_delta_step=4, classifier__max_depth=4, classifier__min_child_weight=3.26797539727096, classifier__n_estimators=650; total time=   3.7s
# [CV] END classifier__learning_rate=0.11303062920563403, classifier__max_delta_step=7, classifier__max_depth=3, classifier__min_child_weight=1.9535395621105678, classifier__n_estimators=999; total time=   4.2s
# [CV] END classifier__learning_rate=0.11303062920563403, classifier__max_delta_step=7, classifier__max_depth=3, classifier__min_child_weight=1.9535395621105678, classifier__n_estimators=999; total time=   4.3s
# [CV] END classifier__learning_rate=0.11303062920563403, classifier__max_delta_step=7, classifier__max_depth=3, classifier__min_child_weight=1.9535395621105678, classifier__n_estimators=999; total time=   4.1s
# [CV] END classifier__learning_rate=0.11303062920563403, classifier__max_delta_step=7, classifier__max_depth=3, classifier__min_child_weight=1.9535395621105678, classifier__n_estimators=999; total time=   4.5s
# [CV] END classifier__learning_rate=0.11303062920563403, classifier__max_delta_step=7, classifier__max_depth=3, classifier__min_child_weight=1.9535395621105678, classifier__n_estimators=999; total time=   4.5s
# [CV] END classifier__learning_rate=0.08465053583309295, classifier__max_delta_step=9, classifier__max_depth=4, classifier__min_child_weight=3.611806875064082, classifier__n_estimators=904; total time=   4.6s
# [CV] END classifier__learning_rate=0.08465053583309295, classifier__max_delta_step=9, classifier__max_depth=4, classifier__min_child_weight=3.611806875064082, classifier__n_estimators=904; total time=   4.7s
# [CV] END classifier__learning_rate=0.08465053583309295, classifier__max_delta_step=9, classifier__max_depth=4, classifier__min_child_weight=3.611806875064082, classifier__n_estimators=904; total time=   4.7s
# [CV] END classifier__learning_rate=0.08465053583309295, classifier__max_delta_step=9, classifier__max_depth=4, classifier__min_child_weight=3.611806875064082, classifier__n_estimators=904; total time=   4.7s
# [CV] END classifier__learning_rate=0.08465053583309295, classifier__max_delta_step=9, classifier__max_depth=4, classifier__min_child_weight=3.611806875064082, classifier__n_estimators=904; total time=   4.9s
# [CV] END classifier__learning_rate=0.21503772759840106, classifier__max_delta_step=2, classifier__max_depth=3, classifier__min_child_weight=1.9822998269497385, classifier__n_estimators=891; total time=   3.8s
# [CV] END classifier__learning_rate=0.21503772759840106, classifier__max_delta_step=2, classifier__max_depth=3, classifier__min_child_weight=1.9822998269497385, classifier__n_estimators=891; total time=   3.6s
# [CV] END classifier__learning_rate=0.21503772759840106, classifier__max_delta_step=2, classifier__max_depth=3, classifier__min_child_weight=1.9822998269497385, classifier__n_estimators=891; total time=   3.5s
# [CV] END classifier__learning_rate=0.21503772759840106, classifier__max_delta_step=2, classifier__max_depth=3, classifier__min_child_weight=1.9822998269497385, classifier__n_estimators=891; total time=   3.5s
# [CV] END classifier__learning_rate=0.21503772759840106, classifier__max_delta_step=2, classifier__max_depth=3, classifier__min_child_weight=1.9822998269497385, classifier__n_estimators=891; total time=   3.5s
# [CV] END classifier__learning_rate=0.2220814459421972, classifier__max_delta_step=5, classifier__max_depth=4, classifier__min_child_weight=2.0228065060130658, classifier__n_estimators=939; total time=   4.5s
# [CV] END classifier__learning_rate=0.2220814459421972, classifier__max_delta_step=5, classifier__max_depth=4, classifier__min_child_weight=2.0228065060130658, classifier__n_estimators=939; total time=   4.6s
# [CV] END classifier__learning_rate=0.2220814459421972, classifier__max_delta_step=5, classifier__max_depth=4, classifier__min_child_weight=2.0228065060130658, classifier__n_estimators=939; total time=   4.8s
# [CV] END classifier__learning_rate=0.2220814459421972, classifier__max_delta_step=5, classifier__max_depth=4, classifier__min_child_weight=2.0228065060130658, classifier__n_estimators=939; total time=   4.9s
# [CV] END classifier__learning_rate=0.2220814459421972, classifier__max_delta_step=5, classifier__max_depth=4, classifier__min_child_weight=2.0228065060130658, classifier__n_estimators=939; total time=   4.5s
# [CV] END classifier__learning_rate=0.08602318990612283, classifier__max_delta_step=7, classifier__max_depth=4, classifier__min_child_weight=3.3922342971346597, classifier__n_estimators=943; total time=   5.0s
# [CV] END classifier__learning_rate=0.08602318990612283, classifier__max_delta_step=7, classifier__max_depth=4, classifier__min_child_weight=3.3922342971346597, classifier__n_estimators=943; total time=   5.9s
# [CV] END classifier__learning_rate=0.08602318990612283, classifier__max_delta_step=7, classifier__max_depth=4, classifier__min_child_weight=3.3922342971346597, classifier__n_estimators=943; total time=   5.5s
# [CV] END classifier__learning_rate=0.08602318990612283, classifier__max_delta_step=7, classifier__max_depth=4, classifier__min_child_weight=3.3922342971346597, classifier__n_estimators=943; total time=   6.3s
# [CV] END classifier__learning_rate=0.08602318990612283, classifier__max_delta_step=7, classifier__max_depth=4, classifier__min_child_weight=3.3922342971346597, classifier__n_estimators=943; total time=   5.3s
# [CV] END classifier__learning_rate=0.0472525312413173, classifier__max_delta_step=6, classifier__max_depth=2, classifier__min_child_weight=1.7728767506843577, classifier__n_estimators=522; total time=   1.6s
# [CV] END classifier__learning_rate=0.0472525312413173, classifier__max_delta_step=6, classifier__max_depth=2, classifier__min_child_weight=1.7728767506843577, classifier__n_estimators=522; total time=   1.7s
# [CV] END classifier__learning_rate=0.0472525312413173, classifier__max_delta_step=6, classifier__max_depth=2, classifier__min_child_weight=1.7728767506843577, classifier__n_estimators=522; total time=   1.7s
# [CV] END classifier__learning_rate=0.0472525312413173, classifier__max_delta_step=6, classifier__max_depth=2, classifier__min_child_weight=1.7728767506843577, classifier__n_estimators=522; total time=   1.8s
# [CV] END classifier__learning_rate=0.0472525312413173, classifier__max_delta_step=6, classifier__max_depth=2, classifier__min_child_weight=1.7728767506843577, classifier__n_estimators=522; total time=   1.7s
# [CV] END classifier__learning_rate=0.25119811669324904, classifier__max_delta_step=8, classifier__max_depth=2, classifier__min_child_weight=1.3809013949306463, classifier__n_estimators=821; total time=   2.3s
# [CV] END classifier__learning_rate=0.25119811669324904, classifier__max_delta_step=8, classifier__max_depth=2, classifier__min_child_weight=1.3809013949306463, classifier__n_estimators=821; total time=   2.3s
# [CV] END classifier__learning_rate=0.25119811669324904, classifier__max_delta_step=8, classifier__max_depth=2, classifier__min_child_weight=1.3809013949306463, classifier__n_estimators=821; total time=   2.5s
# [CV] END classifier__learning_rate=0.25119811669324904, classifier__max_delta_step=8, classifier__max_depth=2, classifier__min_child_weight=1.3809013949306463, classifier__n_estimators=821; total time=   2.4s
# [CV] END classifier__learning_rate=0.25119811669324904, classifier__max_delta_step=8, classifier__max_depth=2, classifier__min_child_weight=1.3809013949306463, classifier__n_estimators=821; total time=   2.4s
# [CV] END classifier__learning_rate=0.27436201636748425, classifier__max_delta_step=1, classifier__max_depth=3, classifier__min_child_weight=4.677534294159395, classifier__n_estimators=896; total time=   3.6s
# [CV] END classifier__learning_rate=0.27436201636748425, classifier__max_delta_step=1, classifier__max_depth=3, classifier__min_child_weight=4.677534294159395, classifier__n_estimators=896; total time=   3.1s
# [CV] END classifier__learning_rate=0.27436201636748425, classifier__max_delta_step=1, classifier__max_depth=3, classifier__min_child_weight=4.677534294159395, classifier__n_estimators=896; total time=   2.9s
# [CV] END classifier__learning_rate=0.27436201636748425, classifier__max_delta_step=1, classifier__max_depth=3, classifier__min_child_weight=4.677534294159395, classifier__n_estimators=896; total time=   3.3s
# [CV] END classifier__learning_rate=0.27436201636748425, classifier__max_delta_step=1, classifier__max_depth=3, classifier__min_child_weight=4.677534294159395, classifier__n_estimators=896; total time=   3.6s
# [CV] END classifier__learning_rate=0.004947380444989273, classifier__max_delta_step=2, classifier__max_depth=4, classifier__min_child_weight=2.515261006446825, classifier__n_estimators=878; total time=   7.3s
# [CV] END classifier__learning_rate=0.004947380444989273, classifier__max_delta_step=2, classifier__max_depth=4, classifier__min_child_weight=2.515261006446825, classifier__n_estimators=878; total time=   7.8s
# [CV] END classifier__learning_rate=0.004947380444989273, classifier__max_delta_step=2, classifier__max_depth=4, classifier__min_child_weight=2.515261006446825, classifier__n_estimators=878; total time=   7.7s
# [CV] END classifier__learning_rate=0.004947380444989273, classifier__max_delta_step=2, classifier__max_depth=4, classifier__min_child_weight=2.515261006446825, classifier__n_estimators=878; total time=   7.9s
# [CV] END classifier__learning_rate=0.004947380444989273, classifier__max_delta_step=2, classifier__max_depth=4, classifier__min_child_weight=2.515261006446825, classifier__n_estimators=878; total time=   7.7s
# [CV] END classifier__learning_rate=0.07378553305786321, classifier__max_delta_step=2, classifier__max_depth=4, classifier__min_child_weight=4.040878353319817, classifier__n_estimators=605; total time=   4.0s
# [CV] END classifier__learning_rate=0.07378553305786321, classifier__max_delta_step=2, classifier__max_depth=4, classifier__min_child_weight=4.040878353319817, classifier__n_estimators=605; total time=   3.8s
# [CV] END classifier__learning_rate=0.07378553305786321, classifier__max_delta_step=2, classifier__max_depth=4, classifier__min_child_weight=4.040878353319817, classifier__n_estimators=605; total time=   3.7s
# [CV] END classifier__learning_rate=0.07378553305786321, classifier__max_delta_step=2, classifier__max_depth=4, classifier__min_child_weight=4.040878353319817, classifier__n_estimators=605; total time=   3.7s
# [CV] END classifier__learning_rate=0.07378553305786321, classifier__max_delta_step=2, classifier__max_depth=4, classifier__min_child_weight=4.040878353319817, classifier__n_estimators=605; total time=   3.5s
# [CV] END classifier__learning_rate=0.04910118716586016, classifier__max_delta_step=4, classifier__max_depth=4, classifier__min_child_weight=4.698199838811912, classifier__n_estimators=843; total time=   5.4s
# [CV] END classifier__learning_rate=0.04910118716586016, classifier__max_delta_step=4, classifier__max_depth=4, classifier__min_child_weight=4.698199838811912, classifier__n_estimators=843; total time=   5.4s
# [CV] END classifier__learning_rate=0.04910118716586016, classifier__max_delta_step=4, classifier__max_depth=4, classifier__min_child_weight=4.698199838811912, classifier__n_estimators=843; total time=   4.9s
# [CV] END classifier__learning_rate=0.04910118716586016, classifier__max_delta_step=4, classifier__max_depth=4, classifier__min_child_weight=4.698199838811912, classifier__n_estimators=843; total time=   5.5s
# [CV] END classifier__learning_rate=0.04910118716586016, classifier__max_delta_step=4, classifier__max_depth=4, classifier__min_child_weight=4.698199838811912, classifier__n_estimators=843; total time=   4.9s
# [CV] END classifier__learning_rate=0.25413220629713285, classifier__max_delta_step=3, classifier__max_depth=2, classifier__min_child_weight=2.9709422066022846, classifier__n_estimators=931; total time=   2.5s
# [CV] END classifier__learning_rate=0.25413220629713285, classifier__max_delta_step=3, classifier__max_depth=2, classifier__min_child_weight=2.9709422066022846, classifier__n_estimators=931; total time=   2.3s
# [CV] END classifier__learning_rate=0.25413220629713285, classifier__max_delta_step=3, classifier__max_depth=2, classifier__min_child_weight=2.9709422066022846, classifier__n_estimators=931; total time=   2.4s
# [CV] END classifier__learning_rate=0.25413220629713285, classifier__max_delta_step=3, classifier__max_depth=2, classifier__min_child_weight=2.9709422066022846, classifier__n_estimators=931; total time=   2.7s
# [CV] END classifier__learning_rate=0.25413220629713285, classifier__max_delta_step=3, classifier__max_depth=2, classifier__min_child_weight=2.9709422066022846, classifier__n_estimators=931; total time=   2.8s
# [CV] END classifier__learning_rate=0.07691825766483047, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=1.2105421702682768, classifier__n_estimators=565; total time=   2.2s
# [CV] END classifier__learning_rate=0.07691825766483047, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=1.2105421702682768, classifier__n_estimators=565; total time=   2.0s
# [CV] END classifier__learning_rate=0.07691825766483047, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=1.2105421702682768, classifier__n_estimators=565; total time=   2.1s
# [CV] END classifier__learning_rate=0.07691825766483047, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=1.2105421702682768, classifier__n_estimators=565; total time=   2.3s
# [CV] END classifier__learning_rate=0.07691825766483047, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=1.2105421702682768, classifier__n_estimators=565; total time=   2.5s
# [CV] END classifier__learning_rate=0.09342959765859114, classifier__max_delta_step=0, classifier__max_depth=4, classifier__min_child_weight=2.1411903155342515, classifier__n_estimators=893; total time=   5.7s
# [CV] END classifier__learning_rate=0.09342959765859114, classifier__max_delta_step=0, classifier__max_depth=4, classifier__min_child_weight=2.1411903155342515, classifier__n_estimators=893; total time=   5.7s
# [CV] END classifier__learning_rate=0.09342959765859114, classifier__max_delta_step=0, classifier__max_depth=4, classifier__min_child_weight=2.1411903155342515, classifier__n_estimators=893; total time=   6.1s
# [CV] END classifier__learning_rate=0.09342959765859114, classifier__max_delta_step=0, classifier__max_depth=4, classifier__min_child_weight=2.1411903155342515, classifier__n_estimators=893; total time=   6.8s
# [CV] END classifier__learning_rate=0.09342959765859114, classifier__max_delta_step=0, classifier__max_depth=4, classifier__min_child_weight=2.1411903155342515, classifier__n_estimators=893; total time=   5.8s
# [CV] END classifier__learning_rate=0.20313686519644347, classifier__max_delta_step=10, classifier__max_depth=4, classifier__min_child_weight=2.9956890943940753, classifier__n_estimators=959; total time=   4.7s
# [CV] END classifier__learning_rate=0.20313686519644347, classifier__max_delta_step=10, classifier__max_depth=4, classifier__min_child_weight=2.9956890943940753, classifier__n_estimators=959; total time=   4.9s
# [CV] END classifier__learning_rate=0.20313686519644347, classifier__max_delta_step=10, classifier__max_depth=4, classifier__min_child_weight=2.9956890943940753, classifier__n_estimators=959; total time=   5.2s
# [CV] END classifier__learning_rate=0.20313686519644347, classifier__max_delta_step=10, classifier__max_depth=4, classifier__min_child_weight=2.9956890943940753, classifier__n_estimators=959; total time=   5.1s
# [CV] END classifier__learning_rate=0.20313686519644347, classifier__max_delta_step=10, classifier__max_depth=4, classifier__min_child_weight=2.9956890943940753, classifier__n_estimators=959; total time=   4.3s
# [CV] END classifier__learning_rate=0.03566629426499684, classifier__max_delta_step=6, classifier__max_depth=2, classifier__min_child_weight=3.2721874165972062, classifier__n_estimators=512; total time=   1.5s
# [CV] END classifier__learning_rate=0.03566629426499684, classifier__max_delta_step=6, classifier__max_depth=2, classifier__min_child_weight=3.2721874165972062, classifier__n_estimators=512; total time=   1.6s
# [CV] END classifier__learning_rate=0.03566629426499684, classifier__max_delta_step=6, classifier__max_depth=2, classifier__min_child_weight=3.2721874165972062, classifier__n_estimators=512; total time=   1.8s
# [CV] END classifier__learning_rate=0.03566629426499684, classifier__max_delta_step=6, classifier__max_depth=2, classifier__min_child_weight=3.2721874165972062, classifier__n_estimators=512; total time=   1.9s
# [CV] END classifier__learning_rate=0.03566629426499684, classifier__max_delta_step=6, classifier__max_depth=2, classifier__min_child_weight=3.2721874165972062, classifier__n_estimators=512; total time=   1.8s
# [CV] END classifier__learning_rate=0.11643525609096508, classifier__max_delta_step=8, classifier__max_depth=4, classifier__min_child_weight=1.3123043869231885, classifier__n_estimators=766; total time=   4.6s
# [CV] END classifier__learning_rate=0.11643525609096508, classifier__max_delta_step=8, classifier__max_depth=4, classifier__min_child_weight=1.3123043869231885, classifier__n_estimators=766; total time=   5.1s
# [CV] END classifier__learning_rate=0.11643525609096508, classifier__max_delta_step=8, classifier__max_depth=4, classifier__min_child_weight=1.3123043869231885, classifier__n_estimators=766; total time=   6.1s
# [CV] END classifier__learning_rate=0.11643525609096508, classifier__max_delta_step=8, classifier__max_depth=4, classifier__min_child_weight=1.3123043869231885, classifier__n_estimators=766; total time=   5.8s
# [CV] END classifier__learning_rate=0.11643525609096508, classifier__max_delta_step=8, classifier__max_depth=4, classifier__min_child_weight=1.3123043869231885, classifier__n_estimators=766; total time=   5.2s
# [CV] END classifier__learning_rate=0.2888848427466392, classifier__max_delta_step=3, classifier__max_depth=4, classifier__min_child_weight=1.8946131079604445, classifier__n_estimators=692; total time=   3.7s
# [CV] END classifier__learning_rate=0.2888848427466392, classifier__max_delta_step=3, classifier__max_depth=4, classifier__min_child_weight=1.8946131079604445, classifier__n_estimators=692; total time=   3.9s
# [CV] END classifier__learning_rate=0.2888848427466392, classifier__max_delta_step=3, classifier__max_depth=4, classifier__min_child_weight=1.8946131079604445, classifier__n_estimators=692; total time=   3.5s
# [CV] END classifier__learning_rate=0.2888848427466392, classifier__max_delta_step=3, classifier__max_depth=4, classifier__min_child_weight=1.8946131079604445, classifier__n_estimators=692; total time=   4.1s
# [CV] END classifier__learning_rate=0.2888848427466392, classifier__max_delta_step=3, classifier__max_depth=4, classifier__min_child_weight=1.8946131079604445, classifier__n_estimators=692; total time=   4.0s
# [CV] END classifier__learning_rate=0.2202446195038405, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=4.216338429909334, classifier__n_estimators=520; total time=   1.6s
# [CV] END classifier__learning_rate=0.2202446195038405, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=4.216338429909334, classifier__n_estimators=520; total time=   1.5s
# [CV] END classifier__learning_rate=0.2202446195038405, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=4.216338429909334, classifier__n_estimators=520; total time=   1.4s
# [CV] END classifier__learning_rate=0.2202446195038405, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=4.216338429909334, classifier__n_estimators=520; total time=   1.4s
# [CV] END classifier__learning_rate=0.2202446195038405, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=4.216338429909334, classifier__n_estimators=520; total time=   1.4s
# [CV] END classifier__learning_rate=0.24934565702176245, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=1.292091740995984, classifier__n_estimators=568; total time=   1.8s
# [CV] END classifier__learning_rate=0.24934565702176245, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=1.292091740995984, classifier__n_estimators=568; total time=   2.2s
# [CV] END classifier__learning_rate=0.24934565702176245, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=1.292091740995984, classifier__n_estimators=568; total time=   1.7s
# [CV] END classifier__learning_rate=0.24934565702176245, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=1.292091740995984, classifier__n_estimators=568; total time=   1.8s
# [CV] END classifier__learning_rate=0.24934565702176245, classifier__max_delta_step=5, classifier__max_depth=2, classifier__min_child_weight=1.292091740995984, classifier__n_estimators=568; total time=   1.7s
# Accuracy:  95.0 %

# %% [markdown]
# We managed to improve the accuracy to 95% wich is very satisfying !

# %% [markdown]
# 4. **INTERPRETATION AND ANALYSIS**

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
#  1    7619
#  0    2651
# -1    1730
# Name: count, dtype: int64

# %%
vaderScores.describe()
# Out:
#           vader_neg     vader_neu     vader_pos    vader_comp        target
# count  12000.000000  12000.000000  12000.000000  12000.000000  12000.000000
# mean       0.054406      0.458620      0.475390      0.246269      0.490750
# std        0.142338      0.376102      0.408828      0.398420      0.733684
# min        0.000000      0.000000      0.000000     -0.970900     -1.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.408000      0.511000      0.421500      1.000000
# 75%        0.000000      0.807000      0.857000      0.458800      1.000000
# max        1.000000      1.000000      1.000000      0.979700      1.000000

# %% [markdown]
# SENTIMENT DISTRIBUTION

# %%
# Create the bar plot
sns.set_style('whitegrid')
plt.figure(figsize=(10, 6))
sns.countplot(x='sentiment', data=df, palette='Purples')

# Customize the plot
plt.title('Sentiment Distribution', fontsize=16)
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.xticks(ticks = [0,1,2], labels=['Negative', 'Neutral', 'Positive'], fontsize=12)
plt.grid(alpha = 0.2)

plt.show()
# Out:
# /var/folders/xk/_lxyx6nn61b0nzyx5vp0p0ph0000gn/T/ipykernel_80109/4022168958.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sentiment', data=df, palette='Purples')

# %% [markdown]
# Great news for Uber, the overall comments are positive !
#
#
# But let is try to go deeper in the analysis using the vader_comp score to visualize the 'intensity' of the sentiment. How positive are positive commments ?

# %%
# Create the histogram
sns.set_style('whitegrid')
plt.figure(figsize=(12, 8))
sns.histplot(x=vaderScores['vader_comp'], color='Purple')

#customize it
plt.title(' Sentiment Distribution', fontsize=14)
plt.xlabel('sentiment intensity')
plt.grid(alpha=0.2)

plt.show()

# %% [markdown]
# We understand here that the satisfaction is pretty moderated, uber consumer being mostly neutral or pretty satisfied about the service. Let is try to have more insights by looking at the distribution for each category

# %%
# Create the visual
sns.set_style('whitegrid')
plt.figure(figsize=(18, 6))

# Subplot for positive comments
plt.subplot(1, 3, 3)  
positive_comments = vaderScores[vaderScores['vader_comp'] >= 0.05]
sns.histplot(x=positive_comments['vader_comp'], color='Purple')
plt.title('Positive Sentiment', fontsize=14)
plt.grid(alpha=0.2)

# Subplot for negative comments
plt.subplot(1, 3, 1)  
negative_comments = vaderScores[vaderScores['vader_comp'] <= -0.05]
sns.histplot(x=negative_comments['vader_comp'], color='Purple')
plt.title('Negative Sentiment', fontsize=14)
plt.grid(alpha=0.2)

# Subplot for neutral comments
plt.subplot(1, 3, 2)  
neutral_comments = vaderScores[(vaderScores['vader_comp'] > -0.05) & (vaderScores['vader_comp'] < 0.05)]
sns.histplot(x=neutral_comments['vader_comp'], color='Purple')
plt.title('Neutral Sentiment', fontsize=14)
plt.grid(alpha=0.2)

# Show the plot
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %% [markdown]
# We can observe that negative comment are more or less normally distributed. Just like positive comments, the instensity is moderated with a minority of extreme values.

# %% [markdown]
# SENTIMENT OVER TIME
#
# Before starting our analysis, it is necesseary to adaprt the target column for more readability of the visuals. Let is use on ecolumn for the day and another for the hour

# %%
df['date'] = df['at'].dt.date
df['hour'] = df['at'].dt.hour

# %% [markdown]
# First let is try to see if there are any significant evolutions of the sentiment between the end of November and mid December : the period of time under analysis

# %%
# Group the data by date and sentiment to get the count of each sentiment over time
df_grouped = df.groupby(['date', 'sentiment']).size().reset_index(name='counts')

# Cretate the visual
sns.set_style('whitegrid')
plt.figure(figsize=(12, 6))

# Plot the negative sentiment over time
sns.lineplot(x='date', y='counts', data=df_grouped[df_grouped['sentiment'] == -1], label='Negative', color='red')

# Plot the neutral sentiment over time
sns.lineplot(x='date', y='counts', data=df_grouped[df_grouped['sentiment'] == 0], label='Neutral', color='grey')

# Plot the positive sentiment over time
sns.lineplot(x='date', y='counts', data=df_grouped[df_grouped['sentiment'] == 1], label='Positive', color='green')

# Customize the plot
plt.title('Sentiment Over Time', fontsize=16)
plt.xlabel('Time')
plt.ylabel('Sentiment Intensity (Counts)')
plt.legend(title='Sentiment')
plt.grid(alpha=0.2)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# It seems that between Dcember 1st and 3rd people were particularly satisfied about their ride ! We will try to understand why in the last section of this analysis.

# %% [markdown]
# SENTIMENT OVER THE DAY
#
# Are there any patterns in the evolution of the sentiments throughout the day ?

# %%
# Calculate percentage of each sentiment for each hour
sentiment_by_hour = pd.DataFrame()
total_by_hour = df.groupby('hour').size()
for sentiment, label in zip([1, 0, -1], ['Positive', 'Neutral', 'Negative']):
    sentiment_counts = df[df['sentiment'] == sentiment].groupby('hour').size()
    sentiment_percentage = (sentiment_counts / total_by_hour * 100)
    sentiment_by_hour[label] = sentiment_percentage

# Create the stacked area plot
plt.figure(figsize=(12, 6))
plt.stackplot(sentiment_by_hour.index, 
              sentiment_by_hour['Positive'],
              sentiment_by_hour['Neutral'],
              sentiment_by_hour['Negative'],
              labels=['Positive', 'Neutral', 'Negative'],
              colors=['#2ecc71', '#95a5a6', '#e74c3c'],
              )

# Customize the plot
plt.title('Sentiment Distribution by Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Percentage of Comments')
plt.legend()
plt.grid(False)

# Set x-axis ticks to show all hours
plt.xticks(range(0,23))

#print the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Except a slight decrease of the positive comments and increase of the negative ones between 2am and 5am, there is nothing really significant to highlight.

# %% [markdown]
# WHAT EXPLAINS SENTIMENTS
#
# Let is try now to focus on the content of both positive and negative sentiment. By retrieving for each category the most common words we may have a better understand of what caused such feelings.
#
# We will start by the negative sentiment since it is the most concerning.

# %%
# Load stop words
negative_comments = df[df['sentiment'] ==-1]
stop_words = set(stopwords.words('english'))

# Exclude the word 'uber' from the stop words
stop_words.update(['uber'])

# Combine all negative comments into a single text string and tokenize
all_words = " ".join(negative_comments['original_content'].astype(str))
tokens = nltk.word_tokenize(all_words)

# Simple filtering approach
filtered_words = [
    word.lower() for word in tokens
    if word.isalpha()
    and word.lower() not in stop_words
    and len(word) > 2
]

# Generate word frequency dictionary
word_counts = dict(Counter(filtered_words))

# Create and configure word cloud
wordcloud = WordCloud(
    width=1200,
    height=600,
    background_color='white',
    colormap='magma',
    max_words=100,
).generate_from_frequencies(word_counts)

# Display the word cloud
plt.figure(figsize=(15, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud of Most Common Words in Negative Sentiment Comments", fontsize=16)
plt.show()

# %% [markdown]
# We can identify different groups of words and try to "clusterize" them in order to get relevant information:
# 2 main problems :
# - First it appears pretty clearly that the main reason of the discontentment of people is the driver
# - Then comes the app
#
# And other one less important :
# - scams /extra fees
# - paiment method
# - cancellation
# - Delay / waiting time
#
#
# Now what about the good points ? (which are by the way the more important in numbers)

# %%
# Load stop words
positive_comments = df[df['sentiment'] == 1]
stop_words = set(stopwords.words('english'))

# Exclude the word 'uber' from the stop words
stop_words.update(['uber'])

# Combine all positive comments into a single text string and tokenize
all_words = " ".join(positive_comments['original_content'].astype(str))
tokens = nltk.word_tokenize(all_words)

# Simple filtering approach
filtered_words = [
    word.lower() for word in tokens
    if word.isalpha()
    and word.lower() not in stop_words
    and len(word) > 2  # Remove very short words
]

# Generate word frequency dictionary
word_counts = dict(Counter(filtered_words))

# Create and configure word cloud
wordcloud = WordCloud(
    width=1200,
    height=600,
    background_color='white',
    colormap='magma',
    max_words=100,
).generate_from_frequencies(word_counts)

# Display the word cloud
plt.figure(figsize=(15, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud of Most Common Words in Negative Sentiment Comments", fontsize=16)
plt.show()

# %% [markdown]
# What is striking here is the number of adjectives. People that had a nice trip tend to focus on their feelings more than what explains it.
# However, we can still have a clue on what made this ride so nice :
# -  driver ( with a lot of positice adjective : nice, kind, friendly, professional , polite...)
# -  app
# -  support

# %% [markdown]
# WHAT MADE PEPOLE SO SATISFIED IN EARLY DECEMBER
#
# Let is come back to our previous observation and let is compare the word most retrived in this period of time to the overall most retrieved.

# %%
# Load stop words
stop_words = set(stopwords.words('english'))
stop_words.update(['uber'])
df['date'] = pd.to_datetime(df['date'])

# Filter for dates between December 1st and 3rd
date_mask = (df['date'] >= '2024-12-01') & (df['date'] <= '2024-12-03')
date_filtered_df = df[date_mask]

# Filter negative sentiment comments
positive_comments = date_filtered_df[date_filtered_df['sentiment'] == 1]

# Combine all negative comments into a single text string and tokenize
all_words = " ".join(positive_comments['original_content'].astype(str))
tokens = nltk.word_tokenize(all_words)

# Simple filtering approach
filtered_words = [
    word.lower() for word in tokens
    if word.isalpha()
    and word.lower() not in stop_words
    and len(word) > 2  # Remove very short words
]

# Generate word frequency dictionary
word_counts = dict(Counter(filtered_words))

# Create and configure word cloud
wordcloud = WordCloud(
    width=1200,
    height=600,
    background_color='white',
    colormap='magma',
    max_words=100,
).generate_from_frequencies(word_counts)

# Display the word cloud
plt.figure(figsize=(15, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud of Most Common Words in Negative Comments (Dec 1-3)", fontsize=16)
plt.show()

# %% [markdown]
# Unfortunately, there is not much here to cocnlude since thhe period of time is relatively short and as mentionned previously, satisfied customer tend to focus on emotions. We can however notice a slight increase in the importance of the driver which confirms our previous conclusions : the driver is the main determinant of customer satisfaction.
